# %% [markdown]
# <div  style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://raw.githubusercontent.com/derar-alhussein/Databricks-Certified-Data-Engineer-Professional/main/Includes/images/CDF.png" width="60%">
# </div>

# %%
# %run ../Includes/Copy-Datasets
# Out:
# Data catalog: workspace
# Schema: bookstore_eng_pro

# %%
# %sql
ALTER TABLE customers_silver 
SET TBLPROPERTIES (delta.enableChangeDataFeed = true);

# %%
# %sql
DESCRIBE TABLE EXTENDED customers_silver
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>customer_id</td><td>string</td><td>null</td></tr><tr><td>email</td><td>string</td><td>null</td></tr><tr><td>first_name</td><td>string</td><td>null</td></tr><tr><td>last_name</td><td>string</td><td>null</td></tr><tr><td>gender</td><td>string</td><td>null</td></tr><tr><td>street</td><td>string</td><td>null</td></tr><tr><td>city</td><td>string</td><td>null</td></tr><tr><td>country</td><td>string</td><td>null</td></tr><tr><td>row_time</td><td>timestamp</td><td>null</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Delta Statistics Columns</td><td></td><td></td></tr><tr><td>Column Names</td><td>customer_id, email, country, row_time, last_name, street, gender, first_name, city</td><td></td></tr><tr><td>Column Selection Method</td><td>first-32</td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Catalog</td><td>workspace</td><td></td></tr><tr><td>Database</td><td>bookstore_eng_pro</td><td></td></tr><tr><td>Table</td><td>customers_silver</td><td></td></tr><tr><td>Created Time</td><td>Sun Dec 28 10:28:58 UTC 2025</td><td></td></tr><tr><td>Last Access</td><td>UNKNOWN</td><td></td></tr><tr><td>Created By</td><td>Spark </td><td></td></tr><tr><td>Statistics</td><td>29294 bytes, 582 rows</td><td></td></tr><tr><td>Type</td><td>MANAGED</td><td></td></tr><tr><td>Location</td><td></td><td></td></tr><tr><td>Provider</td><td>delta</td><td></td></tr><tr><td>Owner</td><td>gorintla.bindusekhar@gmail.com</td><td></td></tr><tr><td>Is_managed_location</td><td>true</td><td></td></tr><tr><td>Predictive Optimization</td><td>ENABLE (inherited from METASTORE metastore_aws_us_east_2)</td><td></td></tr><tr><td>Table Properties</td><td>[delta.enableChangeDataFeed=true,delta.enableDeletionVectors=true,delta.enableRowTracking=true,delta.feature.appendOnly=supported,delta.feature.changeDataFeed=supported,delta.feature.deletionVectors=supported,delta.feature.domainMetadata=supported,delta.feature.invariants=supported,delta.feature.rowTracking=supported,delta.minReaderVersion=3,delta.minWriterVersion=7,delta.parquet.compression.codec=zstd,delta.rowTracking.materializedRowCommitVersionColumnName=_row-commit-version-col-df1d2ae4-fd85-4910-9da4-ad17a1be162c,delta.rowTracking.materializedRowIdColumnName=_row-id-col-0790cf08-eb1b-4087-b607-1296c5abfa15,delta.writePartitionColumnsToParquet=true]</td><td></td></tr></tbody></table></div>

# %%
# %sql
DESCRIBE HISTORY customers_silver
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>2</td><td>2025-12-28T10:47:59.000Z</td><td>72779238284679</td><td>gorintla.bindusekhar@gmail.com</td><td>SET TBLPROPERTIES</td><td>Map(properties -> {"delta.enableChangeDataFeed":"true"})</td><td>null</td><td>List(787401301537842)</td><td>1228-102310-yf2r8o4x-v2n</td><td>1</td><td>WriteSerializable</td><td>true</td><td>Map()</td><td>null</td><td>Databricks-Runtime/17.3.x-aarch64-photon-scala2.13</td></tr><tr><td>1</td><td>2025-12-28T10:29:42.000Z</td><td>72779238284679</td><td>gorintla.bindusekhar@gmail.com</td><td>MERGE</td><td>Map(predicate -> ["(customer_id#13721 = customer_id#13594)"], clusterBy -> [], matchedPredicates -> [{"predicate":"(row_time#13729 < row_time#13603)","actionType":"update"}], statsOnLoad -> true, notMatchedBySourcePredicates -> [], notMatchedPredicates -> [{"actionType":"insert"}])</td><td>null</td><td>List(787401301537820)</td><td>1228-102310-yf2r8o4x-v2n</td><td>0</td><td>WriteSerializable</td><td>false</td><td>Map(numTargetRowsCopied -> 0, numTargetRowsDeleted -> 0, numTargetFilesAdded -> 1, numTargetBytesAdded -> 29294, numTargetBytesRemoved -> 0, numTargetDeletionVectorsAdded -> 0, numTargetRowsMatchedUpdated -> 0, executionTimeMs -> 4605, materializeSourceTimeMs -> 1030, numTargetRowsInserted -> 582, numTargetRowsMatchedDeleted -> 0, numTargetDeletionVectorsUpdated -> 0, scanTimeMs -> 1617, numTargetRowsUpdated -> 0, numOutputRows -> 582, numTargetDeletionVectorsRemoved -> 0, numTargetRowsNotMatchedBySourceUpdated -> 0, numTargetChangeFilesAdded -> 0, numSourceRows -> 582, numTargetFilesRemoved -> 0, numTargetRowsNotMatchedBySourceDeleted -> 0, rewriteTimeMs -> 1781)</td><td>null</td><td>Databricks-Runtime/17.3.x-aarch64-photon-scala2.13</td></tr><tr><td>0</td><td>2025-12-28T10:28:59.000Z</td><td>72779238284679</td><td>gorintla.bindusekhar@gmail.com</td><td>CREATE TABLE</td><td>Map(partitionBy -> [], clusterBy -> [], description -> null, isManaged -> true, properties -> {"delta.parquet.compression.codec":"zstd","delta.enableDeletionVectors":"true","delta.writePartitionColumnsToParquet":"true","delta.enableRowTracking":"true","delta.rowTracking.materializedRowCommitVersionColumnName":"_row-commit-version-col-df1d2ae4-fd85-4910-9da4-ad17a1be162c","delta.rowTracking.materializedRowIdColumnName":"_row-id-col-0790cf08-eb1b-4087-b607-1296c5abfa15"}, statsOnLoad -> false)</td><td>null</td><td>List(787401301537820)</td><td>1228-102310-yf2r8o4x-v2n</td><td>null</td><td>WriteSerializable</td><td>true</td><td>Map()</td><td>null</td><td>Databricks-Runtime/17.3.x-aarch64-photon-scala2.13</td></tr></tbody></table></div>

# %%
bookstore.load_new_data()
bookstore.process_bronze()
bookstore.process_orders_silver()
bookstore.process_customers_silver()
# Out:
# Loading kafka-streaming-04.json file to the bookstore dataset

# %%
# %sql
SELECT * 
FROM table_changes("customers_silver", 2)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>email</th><th>first_name</th><th>last_name</th><th>gender</th><th>street</th><th>city</th><th>country</th><th>row_time</th><th>_change_type</th><th>_commit_version</th><th>_commit_timestamp</th></tr></thead><tbody><tr><td>C00519</td><td>cfirebraceif@google.pl</td><td>Clarabelle</td><td>Firebrace</td><td>Agender</td><td>4 Hudson Road</td><td>Melaka</td><td>Malaysia</td><td>2022-03-26T16:42:00.000Z</td><td>update_preimage</td><td>3</td><td>2025-12-28T10:49:41.000Z</td></tr><tr><td>C00519</td><td>cfirebraceif@google.pl</td><td>Clarabelle</td><td>Firebrace</td><td>Agender</td><td>5 Hudson Road</td><td>Melaka</td><td>Malaysia</td><td>2022-04-05T18:14:00.000Z</td><td>update_postimage</td><td>3</td><td>2025-12-28T10:49:41.000Z</td></tr><tr><td>C00522</td><td>cflatleygc@simplemachines.org</td><td>Casie</td><td>Flatley</td><td>Female</td><td>58 Quincy Way</td><td>Frederico Westphalen</td><td>Brazil</td><td>2022-03-26T19:30:00.000Z</td><td>update_preimage</td><td>3</td><td>2025-12-28T10:49:41.000Z</td></tr><tr><td>C00522</td><td>cflatleygc@simplemachines.org</td><td>Casie</td><td>Flatley</td><td>Female</td><td>59 Quincy Way</td><td>Frederico Westphalen</td><td>Brazil</td><td>2022-04-04T20:51:00.000Z</td><td>update_postimage</td><td>3</td><td>2025-12-28T10:49:41.000Z</td></tr><tr><td>C00531</td><td>gforsardd2@reference.com</td><td>Godiva</td><td>Forsard</td><td>Female</td><td>31 John Wall Court</td><td>Siteki</td><td>Swaziland</td><td>2022-03-29T04:35:00.000Z</td><td>update_preimage</td><td>3</td><td>2025-12-28T10:49:41.000Z</td></tr><tr><td>C00531</td><td>gforsardd2@reference.com</td><td>Godiva</td><td>Forsard</td><td>Female</td><td>34 John Wall Court</td><td>Siteki</td><td>Swaziland</td><td>2022-04-07T06:01:00.000Z</td><td>update_postimage</td><td>3</td><td>2025-12-28T10:49:41.000Z</td></tr><tr><td>C00540</td><td>null</td><td>Consuelo</td><td>Francescone</td><td>Female</td><td>9 South Court</td><td>Fort Abbās</td><td>Pakistan</td><td>2022-03-29T13:16:00.000Z</td><td>update_preimage</td><td>3</td><td>2025-12-28T10:49:41.000Z</td></tr><tr><td>C00540</td><td>null</td><td>Consuelo</td><td>Francescone</td><td>Female</td><td>14 South Court</td><td>Fort Abbās</td><td>Pakistan</td><td>2022-04-05T14:25:00.000Z</td><td>update_postimage</td><td>3</td><td>2025-12-28T10:49:41.000Z</td></tr><tr><td>C00546</td><td>null</td><td>Myrtice</td><td>Fritter</td><td>Female</td><td>null</td><td>Orurillo</td><td>Peru</td><td>2022-03-23T18:10:00.000Z</td><td>update_preimage</td><td>3</td><td>2025-12-28T10:49:41.000Z</td></tr><tr><td>C00546</td><td>null</td><td>Myrtice</td><td>Fritter</td><td>Female</td><td>22736 Myrtle Way</td><td>Orurillo</td><td>Peru</td><td>2022-04-12T21:26:00.000Z</td><td>update_postimage</td><td>3</td><td>2025-12-28T10:49:41.000Z</td></tr><tr><td>C00549</td><td>dfudge5u@theatlantic.com</td><td>Dory</td><td>Fudge</td><td>Male</td><td>4 Glendale Trail</td><td>Putina</td><td>Peru</td><td>2022-03-28T21:54:00.000Z</td><td>update_preimage</td><td>3</td><td>2025-12-28T10:49:41.000Z</td></tr><tr><td>C00549</td><td>dfudge5u@theatlantic.com</td><td>Dory</td><td>Fudge</td><td>Male</td><td>14 Glendale Trail</td><td>Putina</td><td>Peru</td><td>2022-04-02T22:43:00.000Z</td><td>update_postimage</td><td>3</td><td>2025-12-28T10:49:41.000Z</td></tr><tr><td>C00552</td><td>afurnival3r@statcounter.com</td><td>Agata</td><td>Furnival</td><td>Female</td><td>4014 Anzinger Drive</td><td>Nakhon Phanom</td><td>Thailand</td><td>2022-03-30T00:47:00.000Z</td><td>update_preimage</td><td>3</td><td>2025-12-28T10:49:41.000Z</td></tr><tr><td>C00552</td><td>afurnival3r@statcounter.com</td><td>Agata</td><td>Furnival</td><td>Female</td><td>4015 Anzinger Drive</td><td>Nakhon Phanom</td><td>Thailand</td><td>2022-04-04T01:29:00.000Z</td><td>update_postimage</td><td>3</td><td>2025-12-28T10:49:41.000Z</td></tr><tr><td>C00555</td><td>sgabitis3u@bl ...

# %%
bookstore.load_new_data()
bookstore.process_bronze()
bookstore.process_orders_silver()
bookstore.process_customers_silver()
# Out:
# Loading kafka-streaming-05.json file to the bookstore dataset

# %%
cdf_df = (spark.readStream
               .format("delta")
               .option("readChangeData", True)
               .option("startingVersion", 2)
               .table("customers_silver"))

display(cdf_df, checkpointLocation = f"{bookstore.checkpoint_path}/tmp/cdf_{time.time()}")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>email</th><th>first_name</th><th>last_name</th><th>gender</th><th>street</th><th>city</th><th>country</th><th>row_time</th><th>_change_type</th><th>_commit_version</th><th>_commit_timestamp</th></tr></thead><tbody><tr><td>C00519</td><td>cfirebraceif@google.pl</td><td>Clarabelle</td><td>Firebrace</td><td>Agender</td><td>4 Hudson Road</td><td>Melaka</td><td>Malaysia</td><td>2022-03-26T16:42:00.000Z</td><td>update_preimage</td><td>3</td><td>2025-12-28T10:49:41.000Z</td></tr><tr><td>C00519</td><td>cfirebraceif@google.pl</td><td>Clarabelle</td><td>Firebrace</td><td>Agender</td><td>5 Hudson Road</td><td>Melaka</td><td>Malaysia</td><td>2022-04-05T18:14:00.000Z</td><td>update_postimage</td><td>3</td><td>2025-12-28T10:49:41.000Z</td></tr><tr><td>C00522</td><td>cflatleygc@simplemachines.org</td><td>Casie</td><td>Flatley</td><td>Female</td><td>58 Quincy Way</td><td>Frederico Westphalen</td><td>Brazil</td><td>2022-03-26T19:30:00.000Z</td><td>update_preimage</td><td>3</td><td>2025-12-28T10:49:41.000Z</td></tr><tr><td>C00522</td><td>cflatleygc@simplemachines.org</td><td>Casie</td><td>Flatley</td><td>Female</td><td>59 Quincy Way</td><td>Frederico Westphalen</td><td>Brazil</td><td>2022-04-04T20:51:00.000Z</td><td>update_postimage</td><td>3</td><td>2025-12-28T10:49:41.000Z</td></tr><tr><td>C00531</td><td>gforsardd2@reference.com</td><td>Godiva</td><td>Forsard</td><td>Female</td><td>31 John Wall Court</td><td>Siteki</td><td>Swaziland</td><td>2022-03-29T04:35:00.000Z</td><td>update_preimage</td><td>3</td><td>2025-12-28T10:49:41.000Z</td></tr><tr><td>C00531</td><td>gforsardd2@reference.com</td><td>Godiva</td><td>Forsard</td><td>Female</td><td>34 John Wall Court</td><td>Siteki</td><td>Swaziland</td><td>2022-04-07T06:01:00.000Z</td><td>update_postimage</td><td>3</td><td>2025-12-28T10:49:41.000Z</td></tr><tr><td>C00540</td><td>null</td><td>Consuelo</td><td>Francescone</td><td>Female</td><td>9 South Court</td><td>Fort Abbās</td><td>Pakistan</td><td>2022-03-29T13:16:00.000Z</td><td>update_preimage</td><td>3</td><td>2025-12-28T10:49:41.000Z</td></tr><tr><td>C00540</td><td>null</td><td>Consuelo</td><td>Francescone</td><td>Female</td><td>14 South Court</td><td>Fort Abbās</td><td>Pakistan</td><td>2022-04-05T14:25:00.000Z</td><td>update_postimage</td><td>3</td><td>2025-12-28T10:49:41.000Z</td></tr><tr><td>C00546</td><td>null</td><td>Myrtice</td><td>Fritter</td><td>Female</td><td>null</td><td>Orurillo</td><td>Peru</td><td>2022-03-23T18:10:00.000Z</td><td>update_preimage</td><td>3</td><td>2025-12-28T10:49:41.000Z</td></tr><tr><td>C00546</td><td>null</td><td>Myrtice</td><td>Fritter</td><td>Female</td><td>22736 Myrtle Way</td><td>Orurillo</td><td>Peru</td><td>2022-04-12T21:26:00.000Z</td><td>update_postimage</td><td>3</td><td>2025-12-28T10:49:41.000Z</td></tr><tr><td>C00549</td><td>dfudge5u@theatlantic.com</td><td>Dory</td><td>Fudge</td><td>Male</td><td>4 Glendale Trail</td><td>Putina</td><td>Peru</td><td>2022-03-28T21:54:00.000Z</td><td>update_preimage</td><td>3</td><td>2025-12-28T10:49:41.000Z</td></tr><tr><td>C00549</td><td>dfudge5u@theatlantic.com</td><td>Dory</td><td>Fudge</td><td>Male</td><td>14 Glendale Trail</td><td>Putina</td><td>Peru</td><td>2022-04-02T22:43:00.000Z</td><td>update_postimage</td><td>3</td><td>2025-12-28T10:49:41.000Z</td></tr><tr><td>C00552</td><td>afurnival3r@statcounter.com</td><td>Agata</td><td>Furnival</td><td>Female</td><td>4014 Anzinger Drive</td><td>Nakhon Phanom</td><td>Thailand</td><td>2022-03-30T00:47:00.000Z</td><td>update_preimage</td><td>3</td><td>2025-12-28T10:49:41.000Z</td></tr><tr><td>C00552</td><td>afurnival3r@statcounter.com</td><td>Agata</td><td>Furnival</td><td>Female</td><td>4015 Anzinger Drive</td><td>Nakhon Phanom</td><td>Thailand</td><td>2022-04-04T01:29:00.000Z</td><td>update_postimage</td><td>3</td><td>2025-12-28T10:49:41.000Z</td></tr><tr><td>C00555</td><td>sgabitis3u@bl ...
